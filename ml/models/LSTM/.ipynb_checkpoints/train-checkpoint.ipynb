# %%
import tensorflow as tf, pandas as pd, numpy as np
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# make sure I can access datatools
import os
import sys
root_dir = '/Users/cerber/Projects/Lambo/ml/'
if root_dir not in sys.path:
    sys.path.append(root_dir)

# %%
from MLDataTools import MLDataSet
from MLDataTools.preprocessing import relative_change_rates, chunks

df = pd.read_csv('../../data/stocks/_SP500.csv')
features = ['Close']
feature_len = len(features)
normalized = np.array(relative_change_rates(df[features].values))
print(normalized.shape)
normalized_df = pd.DataFrame(normalized, dtype=np.float64)
ds = MLDataSet(normalized_df)
# Out:
# (16979, 1)

# %%
vals = normalized_df.values
plt.plot(vals[:200])
plt.show()

# %%
from models.LSTM.LSTM import LSTM
sess = tf.Session()

model = LSTM(
    sess=sess,
    num_layers=2,
    lstm_size=128,
    feature_len=feature_len, 
    num_steps=20,
    epochs=15,
    plot_dir='./plot_dir'
)

# %%
model.build_graph()
# Out:
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:97: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %%
model.train(ds)
# Out:
# Epoch:0 ---- [Learning rate: 0.001000] [test_loss:0.000147]
# Epoch:1 ---- [Learning rate: 0.001000] [test_loss:0.000158]
# Epoch:2 ---- [Learning rate: 0.001000] [test_loss:0.000160]
# Epoch:3 ---- [Learning rate: 0.001000] [test_loss:0.000150]
# Epoch:4 ---- [Learning rate: 0.001000] [test_loss:0.000144]
# Epoch:5 ---- [Learning rate: 0.000990] [test_loss:0.000147]
# Epoch:6 ---- [Learning rate: 0.000980] [test_loss:0.000140]
# Epoch:7 ---- [Learning rate: 0.000970] [test_loss:0.000141]
# Epoch:8 ---- [Learning rate: 0.000961] [test_loss:0.000143]
# Epoch:9 ---- [Learning rate: 0.000951] [test_loss:0.000140]
# Epoch:10 ---- [Learning rate: 0.000941] [test_loss:0.000147]
# Epoch:11 ---- [Learning rate: 0.000932] [test_loss:0.000152]
